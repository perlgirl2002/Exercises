# %%
import pandas as pd

# %%
columns=['PMID', 'Publisher', 'Journal', 'Article', 'Cost']
df = pd.read_csv("C:\\Users\\kim\\Downloads\\WELLCOME\\WELLCOME_APCspend2013_forThinkful.csv", encoding = "ISO-8859-1")
df.columns=columns

# %%
df.head()
# Out:
#                     PMID Publisher                 Journal  \
# 0                    NaN       CUP  Psychological Medicine
# 1             PMC3679557       ACS       Biomacromolecules
# 2  23043264  PMC3506128        ACS              J Med Chem
# 3    23438330 PMC3646402       ACS              J Med Chem
# 4   23438216 PMC3601604        ACS              J Org Chem
#
#                                              Article      Cost
# 0  Reduced parahippocampal cortical thickness in ...     £0.00
# 1  Structural characterization of a Model Gram-ne...  £2381.04
# 2  Fumaroylamino-4,5-epoxymorphinans and related ...   £642.56
# 3  Orvinols with mixed kappa/mu opioid receptor a...   £669.64
# 4  Regioselective opening of myo-inositol orthoes...   £685.88

# %%
df['Journal'] = df['Journal'].str.upper()
df['Journal'] = df['Journal'].str.strip()
df['Journal'].replace('"','')
df_copy = df.copy(deep=True)
df
# Out:
#                                   PMID  \
# 0                                  NaN
# 1                           PMC3679557
# 2                23043264  PMC3506128
# 3                  23438330 PMC3646402
# 4                 23438216 PMC3601604
# 5                           PMC3579457
# 6                           PMC3709265
# 7                 23057412 PMC3495574
# 8                    PMCID: PMC3780468
# 9                    PMCID: PMC3621575
# 10                   PMCID: PMC3739413
# 11                   PMCID: PMC3530961
# 12                   PMCID: PMC3624797
# 13                          PMC3413243
# 14                          PMC3694353
# 15                          PMC3572711
# 16                            22610094
# 17                   PMCID: PMC3586974
# 18        23455506  PMCID: PMC3607399
# 19          PMID: 24015914 PMC3833349
# 20                       : PMC3805332
# 21                                 NaN
# 22            PMCID:\n    PMC3656742\n
# ...

# %%
del df['PMID']
del df['Cost']
del df['Publisher']

# %%
result_df = df.groupby(['Journal']).agg(['count']).reset_index()
columns = (['Journal','count'])
result_df.columns= columns
sorted_df = result_df.sort_values('count', ascending=False)

print(sorted_df.head(5))
# Out:
#                              Journal  count
# 744                         PLOS ONE    190
# 501  JOURNAL OF BIOLOGICAL CHEMISTRY     53
# 677                       NEUROIMAGE     29
# 699           NUCLEIC ACIDS RESEARCH     26
# 738                    PLOS GENETICS     24

# %%
result_df = df_copy.copy(deep=True)

# %%
del result_df['PMID']
del result_df['Publisher']

# %%
result_df['Cost'].replace(regex=True,inplace=True,to_replace=r'£',value=r'')
result_df['Cost'].replace(regex=True,inplace=True,to_replace=r'\$',value=r'')
result_df['Cost'] = grouped['Cost'].apply(pd.to_numeric)
grouped = result_df.groupby(['Journal','Article'])
grouped.describe()
# Out:
#                                                                                                        Cost  \
#                                                                                                       count
# Journal                                            Article
# ACADEMY OF NUTRITION AND DIETETICS                 Parent support and parent mediated behaviours a...   1.0
# ACS CHEMICAL BIOLOGY                               A Novel Allosteric Inhibitor of the Uridine Dip...   1.0
#                                                    Chemical proteomic analysis reveals the drugabi...   1.0
#                                                    Discovery of ?2 Adrenergic Receptor Ligands Usi...   1.0
#                                                    Discovery of an allosteric inhibitor binding si...   1.0
#                                                    Synthesis of alpha-glucan in mycobacteria invol...   1.0
# ...
